# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import cv2
from tensorflow.keras.models import *
from tensorflow.keras.layers import *
import tensorflow as tf
from tensorflow.keras import layers, models
import glob
import os
import pandas as pd
from tqdm import tqdm
import random
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score

import kagglehub

# Download latest version
path = kagglehub.dataset_download("emmarex/plantdisease")

print("Path to dataset files:", path)
# Out:
# 2025-06-19 18:49:04.887585: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1750358945.084276      19 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1750358945.141121      19 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# Path to dataset files: /kaggle/input/plantdisease

# %%
data_dir = '/kaggle/input/plantdisease/PlantVillage'

categories = os.listdir(data_dir)
print("Classes:", categories)

data_dir = '/kaggle/input/plantdisease/PlantVillage'  # adjust if needed

batch_size = 64
img_height = 150
img_width = 150
seed = 123

train_ds = tf.keras.utils.image_dataset_from_directory(
    data_dir,
    validation_split=0.2,
    subset="training",
    seed=seed,
    image_size=(img_height, img_width),
    batch_size=batch_size,
    shuffle=True)

val_ds = tf.keras.utils.image_dataset_from_directory(
    data_dir,
    validation_split=0.2,
    subset="validation",
    seed=seed,
    image_size=(img_height, img_width),
    batch_size=batch_size,
    shuffle=False)

AUTOTUNE = tf.data.AUTOTUNE

train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

num_classes = len(categories)

model = models.Sequential([
    layers.Rescaling(1./255, input_shape=(img_height, img_width, 3)),

    # First Convolutional Block
    layers.Conv2D(32, (3, 3), activation='relu'),
    layers.MaxPooling2D((2, 2)),

    # Second Convolutional Block
    layers.Conv2D(64, (3, 3), activation='relu'),
    layers.MaxPooling2D((2, 2)),

    # Third Convolutional Block
    layers.Conv2D(128, (3, 3), activation='relu'),
    layers.MaxPooling2D((2, 2)),

    # Fourth Convolutional Block
    layers.Conv2D(256, (3, 3), activation='relu'),
    layers.MaxPooling2D((2, 2)),

    # Dense Layers
    layers.Flatten(),
    layers.Dense(512, activation='relu'),
    layers.Dropout(0.5),
    layers.Dense(num_classes, activation='softmax')
])

model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])
# Out:
# Classes: ['Pepper__bell___Bacterial_spot', 'Potato___healthy', 'Tomato_Leaf_Mold', 'Tomato__Tomato_YellowLeaf__Curl_Virus', 'Tomato_Bacterial_spot', 'Tomato_Septoria_leaf_spot', 'Tomato_healthy', 'Tomato_Spider_mites_Two_spotted_spider_mite', 'Tomato_Early_blight', 'Tomato__Target_Spot', 'Pepper__bell___healthy', 'Potato___Late_blight', 'Tomato_Late_blight', 'Potato___Early_blight', 'Tomato__Tomato_mosaic_virus']
# Found 20638 files belonging to 15 classes.
# Using 16511 files for training.
# I0000 00:00:1750358972.488423      19 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13942 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# I0000 00:00:1750358972.489067      19 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 13942 MB memory:  -> device: 1, name: Tesla T4, pci bus id: 0000:00:05.0, compute capability: 7.5
# Found 20638 files belonging to 15 classes.
# Using 4127 files for validation.
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/preprocessing/tf_data_layer.py:19: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
data_dir = "/kaggle/input/plantdisease/PlantVillage"
img_size = 128

categories = os.listdir(data_dir)
print("Classes:", categories)

data = []
labels = []

for i, category in tqdm(enumerate(categories)):
    folder_path = os.path.join(data_dir, category)
    for img in os.listdir(folder_path):
        try:
            img_path = os.path.join(folder_path, img)
            img_arr = cv2.imread(img_path)
            img_arr = cv2.resize(img_arr, (img_size, img_size))
            data.append(img_arr)
            labels.append(i)
        except Exception as e:
            pass  # Skip unreadable images

print("Total images:", len(data))
# Out:
# Classes: ['Pepper__bell___Bacterial_spot', 'Potato___healthy', 'Tomato_Leaf_Mold', 'Tomato__Tomato_YellowLeaf__Curl_Virus', 'Tomato_Bacterial_spot', 'Tomato_Septoria_leaf_spot', 'Tomato_healthy', 'Tomato_Spider_mites_Two_spotted_spider_mite', 'Tomato_Early_blight', 'Tomato__Target_Spot', 'Pepper__bell___healthy', 'Potato___Late_blight', 'Tomato_Late_blight', 'Potato___Early_blight', 'Tomato__Tomato_mosaic_virus']
# 15it [02:18,  9.26s/it]
# Total images: 20638

# %%
fig, axs = plt.subplots(3, 3, figsize = (7, 5))
cnt = 0
for i in range(3):
     for j in range(3):
         axs[i, j].imshow(data[cnt])
         cnt += 1

# %%
data = np.array(data) / 255.0 
labels = np.array(labels)

X_train, X_test, y_train, y_test = train_test_split(data, labels, test_size=0.2, random_state=42)

y_train = to_categorical(y_train, num_classes=len(categories))
y_test = to_categorical(y_test, num_classes=len(categories))

print(f"\nDataset shapes:")
print(f"X_train: {X_train.shape}, y_train: {y_train.shape}")
print(f"X_test: {X_test.shape}, y_test: {y_test.shape}")
# Out:
# Dataset shapes:
# X_train: (16510, 128, 128, 3), y_train: (16510, 15)
# X_test: (4128, 128, 128, 3), y_test: (4128, 15)

# %%
model = Sequential()
model.add(Conv2D(32, (3, 3), activation = 'relu', input_shape=(128, 128, 3)))
model.add(MaxPooling2D(2, 2))
model.add(Conv2D(64, (3, 3), activation = 'relu'))
model.add(MaxPooling2D(2, 2))
model.add(Conv2D(128, (3, 3), activation='relu'))
model.add(MaxPooling2D(2, 2))
model.add(Flatten())
model.add(Dense(64, activation='relu'))
model.add(Dense(15, activation= 'softmax'))
model.summary()
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d_4 (Conv2D)                    │ (None, 126, 126, 32)        │             896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_4 (MaxPooling2D)       │ (None, 63, 63, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_5 (Conv2D)                    │ (None, 61, 61, 64)          │          18,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_5 (MaxPooling2D)       │ (None, 30, 30, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_6 (Conv2D)                    │ (None, 28, 28, 128)         │          73,856 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_6 (MaxPooling2D)       │ (None, 14, 14, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten_1 (Flatten)                  │ (None, 25088)               │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 64)                  │       1,605,696 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_3 (Dense)                      │ (None, 15)                  │             975 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 1,699,919 (6.48 MB)
#  Trainable params: 1,699,919 (6.48 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(optimizer = 'adam', loss='categorical_crossentropy',  metrics=['accuracy'])

model.evaluate(X_test, y_test)

epochs = 50

history = model.fit(
    X_train, y_train,
    batch_size = 64,
    epochs=epochs,
    verbose=1,
    validation_data=(X_test, y_test)
)
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1750359127.197431      66 service.cc:148] XLA service 0x78f1c0046170 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1750359127.198131      66 service.cc:156]   StreamExecutor device (0): Tesla T4, Compute Capability 7.5
# I0000 00:00:1750359127.198151      66 service.cc:156]   StreamExecutor device (1): Tesla T4, Compute Capability 7.5
# I0000 00:00:1750359127.318217      66 cuda_dnn.cc:529] Loaded cuDNN version 90300
#  27/129 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0561 - loss: 2.7164
# I0000 00:00:1750359129.013682      66 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.0568 - loss: 2.7126
# Epoch 1/50
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 20s 57ms/step - accuracy: 0.4019 - loss: 1.8529 - val_accuracy: 0.7083 - val_loss: 0.8852
# Epoch 2/50
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 8s 32ms/step - accuracy: 0.7805 - loss: 0.6679 - val_accuracy: 0.8038 - val_loss: 0.5886
# Epoch 3/50
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 8s 32ms/step - accuracy: 0.8603 - loss: 0.4198 - val_accuracy: 0.8636 - val_loss: 0.4299
# Epoch 4/50
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 8s 32ms/step - accuracy: 0.9089 - loss: 0.2757 - val_accuracy: 0.8849 - val_loss: 0.3439
# Epoch 5/50
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 8s 32ms/step - accuracy: 0.9375 - loss: 0.1956 - val_accuracy: 0.8874 - val_loss: 0.3457
# Epoch 6/50
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 8s 32ms/step - accuracy: 0.9563 - loss: 0.1308 - val_accuracy: 0.8733 - val_loss: 0.3854
# Epoch 7/50
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 8s 32ms/step - accuracy: 0.9693 - loss: 0.1030 - val_accuracy: 0.9116 - val_loss: 0.3030
# Epoch 8/50
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 8s 33ms/step - accuracy: 0.9722 - loss: 0.0821 - val_accuracy: 0.8970 - val_loss: 0.3562
# Epoch 9/50
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 9s 33ms/step - accuracy: 0.9814 - loss: 0.0547 - val_accuracy: 0.8832 - val_loss: 0.4215
# Epoch 10/50
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 9s 33ms/step - accuracy: 0.9848 - loss: 0.0471 - val_accuracy: 0.8915 - val_loss: 0.3832
# Epoch 11/50
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 9s 33ms/step - accuracy: 0.9862 - loss: 0.0390 - val_accuracy: 0.9155 - val_loss: 0.3498
# Epoch 12/50
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 9s 33ms/step - accuracy: 0.9968 - loss: 0.0124 - val_accuracy: 0.9089 - val_loss: 0.3734
# Epoch 13/50
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 8s 33ms/step - accuracy: 0.9840 - loss: 0.0468 - val_accuracy: 0.8992 - val_loss: 0.4281
# Epoch 14/50
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 8s 33ms/step - accuracy: 0.9895 - loss: 0.0351 - val_accuracy: 0.9157 - val_loss: 0.3592
# Epoch 15/50
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 8s 33ms/step - accuracy: 0.9918 - loss: 0.0255 - val_accuracy: 0.8699 - val_loss: 0.5573
# Epoch 16/50
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 8s 32ms/step - accuracy: 0.9856 - loss: 0.0446 - val_accuracy: 0.9084 - val_loss: 0.4176
# Epoch 17/50
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 8s 33ms/step - accuracy: 0.9953 - loss: 0.0154 - val_accuracy: 0.8944 - val_loss: 0.4595
# Epoch 18/50
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 8s 32ms/step - accuracy: 0.9914 - loss: 0.0274 - val_accuracy: 0.9092 - val_loss: 0.4634
# Epoch 19/50
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 8s 33ms/step - accuracy: 0.9878 - loss: 0.0384 - val_accuracy: 0.8929 - val_loss: 0.4790
# Epoch 20/50
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 8s 33ms/step - accuracy: 0.9926 - loss: 0.0232 - val_accuracy: 0.8997 - val_loss: 0.4319
# Epoch 21/50
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 8s 33ms/step - accuracy: 0.9918 - loss: 0.0245 - val_accuracy: 0.9002 - val_loss: 0.4839
# Epoch 22/50
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 8s 33ms/step - accuracy: 0.9972 - loss: 0.0092 - val_accuracy: 0.9135 - val_loss: 0.4111
# Epoch 23/50
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 8s 33ms/step - accuracy: 0.9997 - loss: 0.0023 - val_accuracy: 0.9278 - val_loss: 0.3701
# Epoch 24/50
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 8s 33ms/step - accuracy: 1.0000 - loss: 1.6797e-04 - val_accuracy: 0.9220 - val_loss: 0.4304
# Epoch 25/50
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 8s 33ms/step - accuracy: 1.0000 - loss: 3.7713e-04 - val_accuracy: 0.9297 - val_loss: 0.3976
# Epoch 26/50
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 8s 33ms/step - accuracy: 1.0000 - loss: 1.1353e-04 - val_accuracy: 0.9297 - val_loss: 0.4036
# Epoch 27/50
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 8s 33ms/step - accuracy: 1.0000 - loss: 9.6646e-05 - val_accuracy: 0.9300 - val_loss: 0.4095
# Epoch 28/50
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 8s 33ms/step - accuracy: 1.0000 - loss: 5.7029e-05 - val_accuracy: 0.9288 - val_loss: 0.4162
# Epoch 29/50
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 8s 33ms/step - accuracy: 1.0000 - loss: 1.9398e-04 - val_accuracy: 0.9281 - val_loss: 0.4266
# Epoch 30/50
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 8s 33ms/step - accuracy: 1.0000 - loss: 3.9871e-05 - val_accuracy: 0.9283 - val_loss: 0.4330
# Epoch 31/50
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 8s 33ms/step - accuracy: 1.0000 - loss: 3.1951e-05 - val_accuracy: 0.9285 - val_loss: 0.4345
# Epoch 32/50
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 8s 33ms/step - accuracy: 1.0000 - loss: 2.9632e-05 - val_accuracy: 0.9293 - val_loss: 0.4380
# Epoch 33/50
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 8s 33ms/step - accuracy: 1.0000 - loss: 2.1557e-05 - val_accuracy: 0.9288 - val_loss: 0.4430
# Epoch 34/50
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 8s 33ms/step - accuracy: 1.0000 - loss: 1.8886e-05 - val_accuracy: 0.9278 - val_loss: 0.4476
# Epoch 35/50
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 8s 33ms/step - accuracy: 1.0000 - loss: 1.6413e-05 - val_accuracy: 0.9283 - val_loss: 0.4526
# Epoch 36/50
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 8s 33ms/step - accuracy: 1.0000 - loss: 1.7146e-05 - val_accuracy: 0.9281 - val_loss: 0.4556
# Epoch 37/50
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 8s 33ms/step - accuracy: 1.0000 - loss: 1.3305e-05 - val_accuracy: 0.9288 - val_loss: 0.4616
# Epoch 38/50
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 8s 33ms/step - accuracy: 1.0000 - loss: 1.1110e-05 - val_accuracy: 0.9285 - val_loss: 0.4650
# Epoch 39/50
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 8s 33ms/step - accuracy: 1.0000 - loss: 9.8024e-06 - val_accuracy: 0.9297 - val_loss: 0.4692
# Epoch 40/50
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 8s 33ms/step - accuracy: 1.0000 - loss: 1.0255e-05 - val_accuracy: 0.9288 - val_loss: 0.4744
# Epoch 41/50
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 8s 33ms/step - accuracy: 1.0000 - loss: 8.6147e-06 - val_accuracy: 0.9283 - val_loss: 0.4783
# Epoch 42/50
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 8s 33ms/step - accuracy: 1.0000 - loss: 6.4754e-06 - val_accuracy: 0.9290 - val_loss: 0.4832
# Epoch 43/50
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 8s 33ms/step - accuracy: 1.0000 - loss: 5.8033e-06 - val_accuracy: 0.9285 - val_loss: 0.4867
# Epoch 44/50
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 8s 33ms/step - accuracy: 1.0000 - loss: 5.7396e-06 - val_accuracy: 0.9295 - val_loss: 0.4918
# Epoch 45/50
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 8s 33ms/step - accuracy: 1.0000 - loss: 4.5307e-06 - val_accuracy: 0.9283 - val_loss: 0.4962
# Epoch 46/50
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 9s 33ms/step - accuracy: 1.0000 - loss: 4.3171e-06 - val_accuracy: 0.9288 - val_loss: 0.5013
# Epoch 47/50
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 8s 33ms/step - accuracy: 1.0000 - loss: 3.4780e-06 - val_accuracy: 0.9290 - val_loss: 0.5071
# Epoch 48/50
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 8s 33ms/step - accuracy: 1.0000 - loss: 2.7414e-06 - val_accuracy: 0.9288 - val_loss: 0.5098
# Epoch 49/50
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 8s 33ms/step - accuracy: 1.0000 - loss: 2.9103e-06 - val_accuracy: 0.9290 - val_loss: 0.5146
# Epoch 50/50
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 8s 33ms/step - accuracy: 1.0000 - loss: 2.2465e-06 - val_accuracy: 0.9285 - val_loss: 0.5195

# %%
model.save("Plant_disease_detector.h5")

# %%
def plotmodelhistory(history):
    fig, axs = plt.subplots(1,2,figsize=(15,5))
    # summarize history for accuracy
    axs[0].plot(history.history['accuracy'])
    axs[0].plot(history.history['val_accuracy'])
    axs[0].set_title('Model Accuracy')
    axs[0].set_ylabel('Accuracy')
    axs[0].set_xlabel('Epoch')
    axs[0].legend(['train', 'validate'], loc='upper left')
    # summarize history for loss
    axs[1].plot(history.history['loss'])
    axs[1].plot(history.history['val_loss'])
    axs[1].set_title('Model Loss')
    axs[1].set_ylabel('Loss')
    axs[1].set_xlabel('Epoch')
    axs[1].legend(['train', 'validate'], loc='upper left')
    plt.show()

# # list all data in history
print(history.history.keys())

plotmodelhistory(history)

final_train_acc = history.history['accuracy'][-1] * 100
final_val_acc = history.history['val_accuracy'][-1] * 100
final_train_loss = history.history['loss'][-1] * 100
final_val_loss = history.history['val_loss'][-1] * 100

print("\n Final Training Metrics:")
print(f"• Training Accuracy: {final_train_acc:.2f}%")
print(f"• Validation Accuracy: {final_val_acc:.2f}%")
print(f"• Training Loss: {final_train_loss:.2f}%") 
print(f"• Validation Loss: {final_val_loss:.2f}%")
# Out:
# dict_keys(['accuracy', 'loss', 'val_accuracy', 'val_loss'])
#  Final Training Metrics:
# • Training Accuracy: 100.00%
# • Validation Accuracy: 92.85%
# • Training Loss: 0.00%
# • Validation Loss: 51.95%

# %%
# Get predicted class probabilities
y_pred_probs = model.predict(X_test)

# Convert probabilities to class labels (integers)
y_pred = np.argmax(y_pred_probs, axis=1)  # Predicted classes (0, 1, 2, ...)
y_true = np.argmax(y_test, axis=1)        # True classes (if y_test is one-hot encoded)
# Out:
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix
import random

# 1. First generate predictions if not already done
y_pred_probs = model.predict(X_test)
y_pred = np.argmax(y_pred_probs, axis=1)
y_true = np.argmax(y_test, axis=1)

# 2. Calculate confusion matrix
cm = confusion_matrix(y_true, y_pred)

cm_normalized = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

# Improved confusion matrix visualization
plt.figure(figsize=(15,12))
sns.heatmap(cm_normalized, annot=True, fmt='.2f', cmap='Blues', 
            xticklabels=categories, 
            yticklabels=categories)
plt.title("Normalized Confusion Matrix", fontsize=14)
plt.xlabel('Predicted Label', fontsize=12)
plt.ylabel('True Label', fontsize=12)
plt.xticks(rotation=45, ha='right', fontsize=10)
plt.yticks(rotation=0, fontsize=10)
plt.tight_layout()
plt.show()

# Sample predictions visualization with error handling
plt.figure(figsize=(15,10))
for i in range(9):
    plt.subplot(3,3,i+1)
    rand_idx = random.randint(0, len(X_test)-1)
    
    # Ensure the image is in correct format for display
    display_img = X_test[rand_idx]
    if display_img.max() <= 1.0:  # If normalized to [0,1]
        display_img = (display_img * 255).astype(np.uint8)
    
    plt.imshow(display_img)
    pred = categories[y_pred[rand_idx]]
    true = categories[y_true[rand_idx]]
    color = 'green' if pred == true else 'red'
    plt.title(f"Pred: {pred}\nTrue: {true}", color=color)
    plt.axis('off')
plt.suptitle("Random Sample Predictions", y=1.02, fontsize=16)
plt.tight_layout()
plt.show()
# Out:
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step

# %%
from IPython.display import FileLink

# Create a download link for the model
FileLink("Plant_disease_detector.h5")
# Out:
# /kaggle/working/Plant_disease_detector.h5

# %%
def predict_image(img):
    if isinstance(img, np.ndarray):
        img = Image.fromarray(img)

    img = img.convert('RGB').resize((128, 128), Image.LANCZOS)
    img_array = np.array(img) / 255.0

    # Test-Time Augmentation
    datagen = ImageDataGenerator(
        rotation_range=10,
        width_shift_range=0.1,
        height_shift_range=0.1,
        zoom_range=0.1,
        horizontal_flip=True
    )

    img_array = np.expand_dims(img_array, axis=0)
    preds = model.predict(img_array)[0]

    aug_iter = datagen.flow(img_array, batch_size=1)
    for _ in range(5):
        aug_img = next(aug_iter)
        preds += model.predict(aug_img)[0]

    preds /= 6  # average

    top_indices = np.argsort(preds)[::-1][:3]
    return {categories[i]: float(preds[i]) for i in top_indices}

# !pip install gradio --quiet
import gradio as gr
import cv2
import numpy as np
from PIL import Image

def predict_image(img):
    # Convert Gradio's numpy array to PIL Image if needed
    if isinstance(img, np.ndarray):
        img = Image.fromarray(img)
    
    # Preprocessing pipeline
    try:
        # Convert to RGB if needed
        img = img.convert('RGB')
        
        # Resize with anti-aliasing
        img = img.resize((128, 128), Image.LANCZOS)
        
        # Convert to array and normalize
        img_array = np.array(img) / 255.0
        
        # Add batch dimension
        img_array = np.expand_dims(img_array, axis=0)
        
        # Predict with model
        pred = model.predict(img_array, verbose=0)
        
        # Get top 3 predictions with confidence
        top_indices = np.argsort(pred[0])[::-1][:3]
        return {categories[i]: float(pred[0][i]) for i in top_indices}
    
    except Exception as e:
        print(f"Prediction error: {e}")
        return {"Error": 1.0}

# Enhanced Gradio interface
interface = gr.Interface(
    fn=predict_image,
    inputs=gr.Image(label="Upload Leaf Image", type="pil"),
    outputs=gr.Label(num_top_classes=3, label="Disease Probabilities"),
    title="🌱 Plant Disease Classifier",
    description="Upload a clear image of a plant leaf to detect potential diseases. For best results, use well-lit, focused images of single leaves.",
    allow_flagging="never"
)

interface.launch()
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.3/54.3 MB 33.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 323.6/323.6 kB 20.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 95.3/95.3 kB 5.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.6/11.6 MB 99.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.0/72.0 kB 4.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.4/62.4 kB 3.7 MB/s eta 0:00:00
# /usr/local/lib/python3.11/dist-packages/gradio/interface.py:419: UserWarning: The `allow_flagging` parameter in `Interface` is deprecated.Use `flagging_mode` instead.
#   warnings.warn(
# * Running on local URL:  http://127.0.0.1:7860
# It looks like you are running Gradio on a hosted Jupyter notebook, which requires `share=True`. Automatically setting `share=True` (you can turn this off by setting `share=False` in `launch()` explicitly).
#
# * Running on public URL: https://b558218d092e8b47a2.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://b558218d092e8b47a2.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
